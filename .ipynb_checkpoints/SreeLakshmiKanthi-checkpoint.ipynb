# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# __Data Sourcing__

# %%
#Reading the data from csv file to dataframe
loan_data = pd.read_csv("loan.csv", low_memory=False)

# %% [markdown]
# __Data Cleaning__

# %%
#Check for unnecessary header and footer rows to delete
loan_data.head()
loan_data.tail()
print(loan_data.shape)
#Remove missing value columns if any
loan_data.dropna(axis = 1, how = 'all', inplace = True)
print(loan_data.shape)
# Out:
# (39717, 111)
# (39717, 57)

# %% [markdown]
# <font color=blue>__None of the columns having all null values__</font>

# %%
#plot to understand missing values in each column of the dataset
loan_data.isna().sum()[loan_data.isna().sum()>0].plot(kind='bar')
# Out:
# <Axes: >

# %%
#From above plot we can see that some cloumns have missing values, drop columns where null values are more than 10000
loan_data.drop(loan_data.columns[loan_data.apply(lambda col: col.isna().sum() > 10000)], axis=1, inplace=True)
print(loan_data.shape)
#Remove missing value rows from columns having null vlaues <= 10000
loan_data.dropna(subset=loan_data.columns[loan_data.apply(lambda col: col.isna().sum() <= 10000)], inplace=True)
print(loan_data.shape)
# Out:
# (39717, 53)
# (36431, 53)

# %%
#Drop columns with only one value for all rows . We can't do any analysis on these columns.
loan_data.drop(loan_data.columns[loan_data.apply(lambda col: col.nunique() == 1)], axis=1, inplace=True)
print(loan_data.shape)
# Out:
# (36431, 44)

# %%
#Let us understand the loan_data
print(loan_data.dtypes)
# Out:
# id                           int64
# member_id                    int64
# loan_amnt                    int64
# funded_amnt                  int64
# funded_amnt_inv            float64
# term                        object
# int_rate                    object
# installment                float64
# grade                       object
# sub_grade                   object
# emp_title                   object
# emp_length                  object
# home_ownership              object
# annual_inc                 float64
# verification_status         object
# issue_d                     object
# loan_status                 object
# url                         object
# purpose                     object
# title                       object
# zip_code                    object
# addr_state                  object
# dti                        float64
# delinq_2yrs                  int64
# earliest_cr_line            object
# inq_last_6mths               int64
# open_acc                     int64
# pub_rec                      int64
# revol_bal                    int64
# revol_util                  object
# total_acc                    int64
# out_prncp                  float64
# out_prncp_inv              float64
# total_pymnt                float64
# total_pymnt_inv            float64
# total_rec_prncp            float64
# total_rec_int              float64
# total_rec_late_fee         float64
# recoveries                 float64
# collection_recovery_fee    float64
# last_pymnt_d                object
# last_pymnt_amnt            float64
# last_credit_pull_d          object
# pub_rec_bankruptcies       float64
# dtype: object

# %% [markdown]
# __Standardising Values__

# %%
#Remove % from int_rate
loan_data['int_rate'] = loan_data['int_rate'].apply(lambda x: x.split('%')[0]).astype('float64')
loan_data.info()
#Remove the duplicated rows if any
loan_data.drop_duplicates()
loan_data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36431 entries, 1 to 39623
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       36431 non-null  int64
#  1   member_id                36431 non-null  int64
#  2   loan_amnt                36431 non-null  int64
#  3   funded_amnt              36431 non-null  int64
#  4   funded_amnt_inv          36431 non-null  float64
#  5   term                     36431 non-null  object
#  6   int_rate                 36431 non-null  float64
#  7   installment              36431 non-null  float64
#  8   grade                    36431 non-null  object
#  9   sub_grade                36431 non-null  object
#  10  emp_title                36431 non-null  object
#  11  emp_length               36431 non-null  object
#  12  home_ownership           36431 non-null  object
#  13  annual_inc               36431 non-null  float64
#  14  verification_status      36431 non-null  object
#  15  issue_d                  36431 non-null  object
#  16  loan_status              36431 non-null  object
#  17  url                      36431 non-null  object
#  18  purpose                  36431 non-null  object
#  19  title                    36431 non-null  object
#  20  zip_code                 36431 non-null  object
#  21  addr_state               36431 non-null  object
#  22  dti                      36431 non-null  float64
#  23  delinq_2yrs              36431 non-null  int64
#  24  earliest_cr_line         36431 non-null  object
#  25  inq_last_6mths           36431 non-null  int64
#  26  open_acc                 36431 non-null  int64
#  27  pub_rec                  36431 non-null  int64
#  28  revol_bal                36431 non-null  int64
#  29  revol_util               36431 non-null  object
#  30  total_acc                36431 non-null  int64
#  31  out_prncp                36431 non-null  float64
#  32  out_prncp_inv            36431 non-null  float64
#  33  total_pymnt              36431 non-null  float64
#  34  total_pymnt_inv          36431 non-null  float64
#  35  total_rec_prncp          36431 non-null  float64
#  36  total_rec_int            36431 non-null  float64
#  37  total_rec_late_fee       36431 non-null  float64
#  38  recoveries               36431 non-null  float64
#  39  collection_recovery_fee  36431 non-null  float64
#  40  last_pymnt_d             36431 non-null  object
#  41  last_pymnt_amnt          36431 non-null  float64
#  42  last_credit_pull_d       36431 non-null  object
#  43  pub_rec_bankruptcies     36431 non-null  float64
# dtypes: float64(16), int64(10), object(18)
# memory usage: 12.5+ MB
# (36431, 44)

# %%
#id and member_id are unique values. Cant derive any info from them. Let us drop these columns.
loan_data.drop(["id", "member_id"], axis = 1, inplace = True)

# %%
loan_data.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count  36431.000000  36431.000000     36431.000000  36431.000000
# mean   11307.794186  11032.933491     10601.876895     12.073891
# std     7433.904309   7166.520054      7072.645601      3.734857
# min      500.000000    500.000000         0.000000      5.420000
# 25%     5600.000000   5500.000000      5000.000000      9.320000
# 50%    10000.000000  10000.000000      9203.371902     11.860000
# 75%    15000.000000  15000.000000     14508.774540     14.650000
# max    35000.000000  35000.000000     35000.000000     24.400000
#
#         installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  \
# count  36431.000000  3.643100e+04  36431.000000  36431.000000    36431.000000
# mean     326.187642  6.930694e+04     13.444293      0.146139        0.864840
# std      207.390058  6.354376e+04      6.643417      0.492211        1.063383
# min       16.080000  4.000000e+03      0.000000      0.000000        0.000000
# 25%      168.900000  4.200000e+04      8.360000      0.000000        0.000000
# 50%      283.280000  6.000000e+04     13.540000      0.000000        1.000000
# 75%      432.220000  8.300000e+04     18.690000      0.000000        1.000000
# max     1305.190000  6.000000e+06     29.990000     11.000000        8.000000
#
#            open_acc  ...  out_prncp_inv   total_pymnt  total_pymnt_inv  \
# count  36431.000000  ...   36431.000000  36431.000000     36431.000000
# mean       9.351679  ...      52.216180  12311.226392     11841.691116
# std        4.373724  ...     378.454016   9048.552965      8911.170172
# min        2.000000  ...       0.000000     33.730000         0.000000
# 25%        6.000000  ...       0.000000   5672.634184      5413.880000
# 50%        9.000000  ...       0.000000  10101.589360      9632.410000
# 75%       12.000000  ...       0.000000  16700.865405     16094.780000
# max       44.000000  ...    6307.370000  58563.679930     58563.680000
#
#        total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  \
# count     36431.000000   36431.000000        36431.000000  36431.000000
# mean       9912.631803    2304.442520            1.299912     92.852238
# std        7053.310578    2629.598904            7.065817    682.064837
# min           0.000000       6.220000            0.000000      0.000000
# 25%        4800.000000     678.030000            0.000000      0.000000
# 50%        8123.600000    1379.820000            0.000000      0.000000
# 75%       14000.000000    2891.865000            0.000000      0.000000
# max       35000.020000   23563.680000          180.200000  29623.350000
#
#        collection_recovery_fee  last_pymnt_amnt  pub_rec_bankruptcies
# count             36431.000000     36431.000000          36431.000000
# mean                 11.677622      2743.075381              0.041366
# std                 140.884174      4473.621163              0.200100
# min                   0.000000         0.010000              0.000000
# 25%                   0.000000       226.310000              0.000000
# 50%                   0.000000       571.700000              0.000000
# 75%                   0.000000      3457.620000              0.000000
# max                7002.190000     36115.200000              2.000000
#
# [8 rows x 24 columns]

# %%
#Drop grade & sub grade as these are assigned by LC. Can't derive any metrics. Drop emp_title also, as this is random value.
loan_data.drop(["grade", "sub_grade","emp_title"], axis = 1, inplace = True)
loan_data.shape
# Out:
# (36431, 39)

# %%
#Identify outliers
data_to_plot = loan_data[['loan_amnt', 'funded_amnt', 'funded_amnt_inv']]
data_to_plot.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# <font color=blue>__Seems like continuous data. No outliers.__</font>

# %%
#Identify outliers
data_to_plot = loan_data[['int_rate', 'installment', 'annual_inc']]
data_to_plot.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# <font color=blue> __"annual_inc" has outliers. Let us deal with these outliers__ </font>

# %%
print(loan_data["annual_inc"].describe())
# Out:
# count    3.643100e+04
# mean     6.930694e+04
# std      6.354376e+04
# min      4.000000e+03
# 25%      4.200000e+04
# 50%      6.000000e+04
# 75%      8.300000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
# Remove values greater than 95th percentile
loan_data = loan_data[loan_data["annual_inc"] < loan_data["annual_inc"].quantile(0.95)]
data_to_plot = loan_data[['annual_inc']]
data_to_plot.boxplot()
loan_data.shape
# Out:
# (34482, 39)

# %% [markdown]
# <font color=blue> __After removing values > 0.95 percentile "annual_inc" seems to have continuous data.__ </font>

# %%
#Identify outliers
data_to_plot = loan_data[['dti', 'delinq_2yrs', 'out_prncp_inv']]
data_to_plot.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# <font color=blue> __"out_prncp_inv" has outliers. Let us deal this column__ </font>

# %%
#out_prncp & out_prncp_inv attributes can't influence the tendency of default. As these are for current applicant in the process of paying the installments. Let us drop these columns
loan_data.drop(["out_prncp", "out_prncp_inv"], axis = 1, inplace = True)
loan_data.shape
# Out:
# (34482, 37)

# %% [markdown]
# __Fix invalid values__

# %%
#Remove % from int_rate and convert to float with two decimal places
loan_data['int_rate']=loan_data['int_rate'].apply(lambda x:str(x).replace('%','')).astype('float').round(2)
loan_data.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 1       2500         2500           2500.0   60 months     15.27        59.83
# 3      10000        10000          10000.0   36 months     13.49       339.31
# 4       3000         3000           3000.0   60 months     12.69        67.79
# 5       5000         5000           5000.0   36 months      7.90       156.46
# 6       7000         7000           7000.0   60 months     15.96       170.08
#
#   emp_length home_ownership  annual_inc verification_status  ...  \
# 1   < 1 year           RENT     30000.0     Source Verified  ...
# 3  10+ years           RENT     49200.0     Source Verified  ...
# 4     1 year           RENT     80000.0     Source Verified  ...
# 5    3 years           RENT     36000.0     Source Verified  ...
# 6    8 years           RENT     47004.0        Not Verified  ...
#
#   total_pymnt_inv total_rec_prncp total_rec_int total_rec_late_fee recoveries  \
# 1         1008.71          456.46        435.17               0.00     117.08
# 3        12231.89        10000.00       2214.92              16.97       0.00
# 4         3513.33         2475.94       1037.39               0.00       0.00
# 5         5632.21         5000.00        632.21               0.00       0.00
# 6        10110.84         6985.61       3125.23               0.00       0.00
#
#   collection_recovery_fee last_pymnt_d  last_pymnt_amnt  last_credit_pull_d  \
# 1                    1.11       Apr-13           119.66              Sep-13
# 3                    0.00       Jan-15           357.48              Apr-16
# 4                    0.00       May-16            67.79              May-16
# 5                    0.00       Jan-15           161.03              Jan-16
# 6                    0.00       May-16          1313.76              May-16
#
#   pub_rec_bankruptcies
# 1                  0.0
# 3                  0.0
# 4                  0.0
# 5                  0.0
# 6                  0.0
#
# [5 rows x 37 columns]

# %%
#Derive month and year from issue_d
loan_data['issue_d']=pd.to_datetime(loan_data['issue_d'],format='%b-%y')
loan_data['issue_year']=pd.to_datetime(loan_data['issue_d'],format='%b-%y').dt.year
loan_data['issue_month']=pd.to_datetime(loan_data['issue_d'],format='%b-%y').dt.month
loan_data.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 1       2500         2500           2500.0   60 months     15.27        59.83
# 3      10000        10000          10000.0   36 months     13.49       339.31
# 4       3000         3000           3000.0   60 months     12.69        67.79
# 5       5000         5000           5000.0   36 months      7.90       156.46
# 6       7000         7000           7000.0   60 months     15.96       170.08
#
#   emp_length home_ownership  annual_inc verification_status  ...  \
# 1   < 1 year           RENT     30000.0     Source Verified  ...
# 3  10+ years           RENT     49200.0     Source Verified  ...
# 4     1 year           RENT     80000.0     Source Verified  ...
# 5    3 years           RENT     36000.0     Source Verified  ...
# 6    8 years           RENT     47004.0        Not Verified  ...
#
#   total_rec_int total_rec_late_fee recoveries collection_recovery_fee  \
# 1        435.17               0.00     117.08                    1.11
# 3       2214.92              16.97       0.00                    0.00
# 4       1037.39               0.00       0.00                    0.00
# 5        632.21               0.00       0.00                    0.00
# 6       3125.23               0.00       0.00                    0.00
#
#   last_pymnt_d last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies  \
# 1       Apr-13          119.66             Sep-13                   0.0
# 3       Jan-15          357.48             Apr-16                   0.0
# 4       May-16           67.79             May-16                   0.0
# 5       Jan-15          161.03             Jan-16                   0.0
# 6       May-16         1313.76             May-16                   0.0
#
#    issue_year issue_month
# 1        2011          12
# 3        2011          12
# 4        2011          12
# 5        2011          12
# 6        2011          12
#
# [5 rows x 39 columns]

# %%
#emp_length < 1 year is considered as 0 and 10+ years is considered as 10 
loan_data["emp_length"] = pd.to_numeric(loan_data["emp_length"].apply(lambda x: x.replace('years','').replace('year','').replace('+','').replace('< 1','0')))
loan_data["emp_length"].value_counts()
# Out:
# 10    7788
# 2     3985
# 0     3883
# 3     3716
# 4     3143
# 5     2968
# 1     2897
# 6     2027
# 7     1625
# 8     1312
# 9     1138
# Name: emp_length, dtype: int64

# %% [markdown]
# __Univariate Analysis__

# %%
#From data dictionary we see the term as the number of payments on the loan. Values are in months and can be either 36 or 60. 
#Convert this to a categorical variable 
loan_data['term'] = loan_data['term'].astype('category')
loan_data['term'].value_counts().plot.bar()
(loan_data['term'].value_counts()*100)/len(loan_data)
# Out:
#  36 months    72.7162
#  60 months    27.2838
# Name: term, dtype: float64

# %% [markdown]
# <font color=blue> __73% applicants are with loan term of 36months__ </font>

# %%
#From problem statement we know the loan_status can be fully paid, charged_off or current. 
#Convert this to a categorical variable 
loan_data['loan_status'] = loan_data['loan_status'].astype('category')
loan_data['loan_status'].value_counts().plot.bar()
(loan_data['loan_status'].value_counts()*100)/len(loan_data)
# Out:
# Fully Paid     83.394235
# Charged Off    13.763703
# Current         2.842063
# Name: loan_status, dtype: float64

# %% [markdown]
# <font color=blue> __Around 14% of loan applicants are charged_off__ </font>

# %%
#Convert home_ownership to categorical variable
loan_data['home_ownership']=loan_data['home_ownership'].astype('category')
loan_data['home_ownership'].value_counts().plot.bar()
(loan_data['home_ownership'].value_counts()*100)/len(loan_data)
# Out:
# RENT        49.280784
# MORTGAGE    43.286352
# OWN          7.177658
# OTHER        0.255206
# Name: home_ownership, dtype: float64

# %% [markdown]
# <font color=blue> __Around 49% of loan applicants are having rental accomodation followed by 43% are mortgage__ </font>

# %%
#From problem statement we know the verification_status can be not_verified, verified or source_verified
#Convert to categorical variable
loan_data['verification_status']=loan_data['verification_status'].astype('category')
loan_data['verification_status'].value_counts().plot.bar()
(loan_data['verification_status'].value_counts()*100)/len(loan_data)
# Out:
# Not Verified       42.610637
# Verified           31.546894
# Source Verified    25.842469
# Name: verification_status, dtype: float64

# %% [markdown]
# <font color=blue> __Around 43% of loan applicants are not verified__ </font>

# %%
#From problem statement we know the purpose can be converted to categorical variable
loan_data['purpose']=loan_data['purpose'].astype('category')
loan_data['purpose'].value_counts().plot.bar()
(loan_data['purpose'].value_counts()*100)/len(loan_data)
# Out:
# debt_consolidation    48.361464
# credit_card           12.969085
# other                  9.880517
# home_improvement       6.939853
# major_purchase         5.510121
# car                    4.045589
# small_business         3.799084
# wedding                2.462154
# medical                1.722638
# moving                 1.450032
# vacation               0.942521
# house                  0.916420
# educational            0.768517
# renewable_energy       0.232005
# Name: purpose, dtype: float64

# %% [markdown]
# <font color=blue> __Around 48% of loan applicants have mentioned purpose as debt_consolidation followed by 13% credit card__ </font>

# %% [markdown]
# __Bivariate Analysis__

# %%
# Our aim is to identify the risky loan applicants i.e. loan_status as charged_off . Let us see how other factors are influencing this.
plt.matshow(loan_data.corr(numeric_only = True))
plt.show()
